# %%
#step1: collecting the data
import pandas as pd
df = pd.read_csv("ToyotaCorolla - MLR.csv")

df.shape
df.head()
# Out:
#    Price  Age_08_04     KM Fuel_Type  HP  Automatic    cc  Doors  Cylinders  \
# 0  13500         23  46986    Diesel  90          0  2000      3          4
# 1  13750         23  72937    Diesel  90          0  2000      3          4
# 2  13950         24  41711    Diesel  90          0  2000      3          4
# 3  14950         26  48000    Diesel  90          0  2000      3          4
# 4  13750         30  38500    Diesel  90          0  2000      3          4
#
#    Gears  Weight
# 0      5    1165
# 1      5    1165
# 2      5    1165
# 3      5    1165
# 4      5    1170

# %%
##STEP 2
#.Perform exploratory data analysis (EDA) to gain insights into the dataset. 
#Provide visualizations and summary statistics of the variables. Pre process the data to apply the MLR.

# %%
##STEP 2
## EXPLORATORY DATA ANALYSIS
import matplotlib.pyplot as plt
#	2 a. Construct the box plot for all X variables
plt.boxplot(df['Age_08_04'],vert = False)
plt.show()

plt.boxplot(df['KM'],vert = False)
plt.show()

plt.boxplot(df['HP'],vert = False)
plt.show()

plt.boxplot(df['Automatic'],vert = False)
plt.show()

plt.boxplot(df['cc'],vert = False)
plt.show()

plt.boxplot(df['Doors'],vert = False)
plt.show()

plt.boxplot(df['Cylinders'],vert = False)
plt.show()

plt.boxplot(df['Gears'],vert = False)
plt.show()

plt.boxplot(df['Weight'],vert = False)
plt.show()

##box plot for target variable
plt.boxplot(df['Price'],vert = False)
plt.show()

# %%
#	3. Construct the histogram for all X variables
plt.hist(df["Age_08_04"])
plt.show()
##Price
plt.hist(df["Price"])
plt.show()
##Age_08_04
plt.hist(df["Age_08_04"])
plt.show()
##KM
plt.hist(df["KM"])
plt.show()
##HP
plt.hist(df["HP"])
plt.show()
##Automatic
plt.hist(df["Automatic"])
plt.show()
##cc
plt.hist(df["cc"])
plt.show()
##Doors
plt.hist(df["Doors"])
plt.show()
##Cylinders
plt.hist(df["Cylinders"])
plt.show()
##Gears
plt.hist(df["Gears"])
plt.show()
##Weight
plt.hist(df["Weight"])
plt.show()

# %%
#step 2 b: Bar Chart for Fuel_Type column with target variable
b2=df.groupby("Fuel_Type")["Price"].sum()
b2.plot(kind='bar')
# Out:
# <Axes: xlabel='Fuel_Type'>

# %%
#	2 c.Construct the scatter plot with every X variable with Y.
plt.scatter(df["Age_08_04"],df["Price"])
plt.xlabel("Age_08_04")
plt.ylabel("Price")
plt.show()

plt.scatter(df["KM"],df["Price"])
plt.xlabel("KM")
plt.ylabel("Price")
plt.show()

plt.scatter(df["HP"],df["Price"])
plt.xlabel("HP")
plt.ylabel("Price")
plt.show()

plt.scatter(df["Automatic"],df["Price"])
plt.xlabel("Automatic")
plt.ylabel("Price")
plt.show()

plt.scatter(df["cc"],df["Price"])
plt.xlabel("cc")
plt.ylabel("Price")
plt.show()

plt.scatter(df["Doors"],df["Price"])
plt.xlabel("Doors")
plt.ylabel("Price")
plt.show()

plt.scatter(df["Cylinders"],df["Price"])
plt.xlabel("Cylinders")
plt.ylabel("Price")
plt.show()

plt.scatter(df["Gears"],df["Price"])
plt.xlabel("Gears")
plt.ylabel("Price")
plt.show()

plt.scatter(df["Weight"],df["Price"])
plt.xlabel("Weight")
plt.ylabel("Price")
plt.show()

# %%
df1=df.drop(df.columns[3],axis=1)
df1
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0     13500         23  46986   90          0  2000      3          4      5
# 1     13750         23  72937   90          0  2000      3          4      5
# 2     13950         24  41711   90          0  2000      3          4      5
# 3     14950         26  48000   90          0  2000      3          4      5
# 4     13750         30  38500   90          0  2000      3          4      5
# ...     ...        ...    ...  ...        ...   ...    ...        ...    ...
# 1431   7500         69  20544   86          0  1300      3          4      5
# 1432  10845         72  19000   86          0  1300      3          4      5
# 1433   8500         71  17016   86          0  1300      3          4      5
# 1434   7250         70  16916   86          0  1300      3          4      5
# 1435   6950         76      1  110          0  1600      5          4      5
#
#       Weight
# 0       1165
# 1       1165
# ...

# %%
df1.corr()
# Out:
#               Price  Age_08_04        KM        HP  Automatic        cc  \
# Price      1.000000  -0.876590 -0.569960  0.314990   0.033081  0.126389
# Age_08_04 -0.876590   1.000000  0.505672 -0.156622   0.031717 -0.098084
# KM        -0.569960   0.505672  1.000000 -0.333538  -0.081854  0.102683
# HP         0.314990  -0.156622 -0.333538  1.000000   0.013144  0.035856
# Automatic  0.033081   0.031717 -0.081854  0.013144   1.000000  0.066740
# cc         0.126389  -0.098084  0.102683  0.035856   0.066740  1.000000
# Doors      0.185326  -0.148359 -0.036197  0.092424  -0.027654  0.079903
# Cylinders       NaN        NaN       NaN       NaN        NaN       NaN
# Gears      0.063104  -0.005364  0.015023  0.209477  -0.098555  0.014629
# Weight     0.581198  -0.470253 -0.028598  0.089614   0.057249  0.335637
#
#               Doors  Cylinders     Gears    Weight
# Price      0.185326        NaN  0.063104  0.581198
# Age_08_04 -0.148359        NaN -0.005364 -0.470253
# ...

# %%
##step 3
##DATA TRANSFORMATION

# %%
##CONTINUOUS DATA COLUMNS
df_cont=df[['Age_08_04','KM','HP','Automatic','cc','Doors','Cylinders','Gears','Weight']]

# %%
##STEP 3 a DATA PRE-PROCESSING
# standardization
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()

df_cont['Age_08_04'] = SS.fit_transform(df_cont[['Age_08_04']])
df_cont['KM'] = SS.fit_transform(df_cont[['KM']])
df_cont['HP'] = SS.fit_transform(df_cont[['HP']])

df_cont['Automatic'] = SS.fit_transform(df_cont[['Automatic']])
df_cont['cc'] = SS.fit_transform(df_cont[['cc']])
df_cont['Doors'] = SS.fit_transform(df_cont[['Doors']])

df_cont['Cylinders'] = SS.fit_transform(df_cont[['Cylinders']])
df_cont['Gears'] = SS.fit_transform(df_cont[['Gears']])
df_cont['Weight'] = SS.fit_transform(df_cont[['Weight']])


df_cont.head()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_15292\3100742016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cont['Age_08_04'] = SS.fit_transform(df_cont[['Age_08_04']])
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_15292\3100742016.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cont['KM'] = SS.fit_transform(df_cont[['KM']])
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_15292\3100742016.py:8: SettingWithCopyWarning:
# ...

# %%
##step 3 B
##split X and Y
##performing label encoding on Categorical data
## STEP 3 B Fuel_Type is label encoding column
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["Fuel Type Encoded"]=LE.fit_transform(df['Fuel_Type'])
df["Fuel Type Encoded"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1431    2
# 1432    2
# 1433    2
# 1434    2
# 1435    2
# Name: Fuel Type Encoded, Length: 1436, dtype: int32

# %%
###combining categorical and continuous columns in order to get preprocesing of X variables
#STEP 3 C
##converting the above array into DataFrame
df_cat = pd.DataFrame(df['Fuel Type Encoded'], columns=['Fuel Type Encoded'])
df_cat
# Out:
#       Fuel Type Encoded
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ...                 ...
# 1431                  2
# 1432                  2
# 1433                  2
# 1434                  2
# 1435                  2
#
# [1436 rows x 1 columns]

# %%
##step 3 D
##FINALLY we are combining all the pre-processed variables
##those are X continuous variables and Categorical variables
###we consider the new data that is df_newX for training and testing X variables
df_newX=pd.concat([df_cont,df_cat],axis=1)
df_newX
# Out:
#       Age_08_04        KM        HP  Automatic        cc     Doors  Cylinders  \
# 0     -1.771966 -0.574695 -0.768042  -0.242893  0.997419 -1.085139        0.0
# 1     -1.771966  0.117454 -0.768042  -0.242893  0.997419 -1.085139        0.0
# 2     -1.718184 -0.715386 -0.768042  -0.242893  0.997419 -1.085139        0.0
# 3     -1.610620 -0.547650 -0.768042  -0.242893  0.997419 -1.085139        0.0
# 4     -1.395491 -0.801028 -0.768042  -0.242893  0.997419 -1.085139        0.0
# ...         ...       ...       ...        ...       ...       ...        ...
# 1431   0.702015 -1.279939 -1.035138  -0.242893 -0.652594 -1.085139        0.0
# 1432   0.863362 -1.321120 -1.035138  -0.242893 -0.652594 -1.085139        0.0
# 1433   0.809579 -1.374036 -1.035138  -0.242893 -0.652594 -1.085139        0.0
# 1434   0.755797 -1.376703 -1.035138  -0.242893 -0.652594 -1.085139        0.0
# 1435   1.078490 -1.827849  0.567440  -0.242893  0.054555  1.014941        0.0
#
# ...

# %%
##step 4
##defining target variable
Y=df["Price"]
Y
# Out:
# 0       13500
# 1       13750
# 2       13950
# 3       14950
# 4       13750
#         ...
# 1431     7500
# 1432    10845
# 1433     8500
# 1434     7250
# 1435     6950
# Name: Price, Length: 1436, dtype: int64

# %%
df_newX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age_08_04          1436 non-null   float64
#  1   KM                 1436 non-null   float64
#  2   HP                 1436 non-null   float64
#  3   Automatic          1436 non-null   float64
#  4   cc                 1436 non-null   float64
#  5   Doors              1436 non-null   float64
#  6   Cylinders          1436 non-null   float64
#  7   Gears              1436 non-null   float64
#  8   Weight             1436 non-null   float64
#  9   Fuel Type Encoded  1436 non-null   int32
# dtypes: float64(9), int32(1)
# memory usage: 106.7 KB

# %%
##TASK 2
##2.Split the dataset into training and testing sets (e.g., 80% training, 20% testing).

# %%
#step 3

# %%
##step 3
##TRAINING AND TESTING SPLITTING
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df_newX,Y,test_size=0.2,random_state=10)
#random_state by using this random state the results will never change
x_train.shape
# Out:
# (1148, 10)

# %%
x_test.shape
# Out:
# (288, 10)

# %%
y_train.shape
# Out:
# (1148,)

# %%
##TASK 4
##3.Build a multiple linear regression model using the training dataset. 
#Interpret the coefficients of the model. Build minimum of 3 different models.

# %%
## step 4
####model 1 


Y=df["Price"]

df_newX=df_newX[["Age_08_04"]]


from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(df_newX,Y)
Y_pred=LR.predict(df_newX)

import numpy as np

from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(Y,Y_pred)
print("Mean Square error:",mse.round(3))
print("Root Mean Square error:",np.sqrt(mse).round(3))

print("R sqaure value:",r2_score(Y,Y_pred).round(3))
# Out:
# Mean Square error: 3044403.459
# Root Mean Square error: 1744.822
# R sqaure value: 0.768

# %%
## step 4
####model 2

Y=df["Price"]

df_newX=df_newX[["Age_08_04","Weight"]]


from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(df_newX,Y)
Y_pred=LR.predict(df_newX)

import numpy as np

from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(Y,Y_pred)
print("Mean Square error:",mse.round(3))
print("Root Mean Square error:",np.sqrt(mse).round(3))

print("R sqaure value:",r2_score(Y,Y_pred).round(3))
# Out:
# Mean Square error: 2562472.821
# Root Mean Square error: 1600.773
# R sqaure value: 0.805

# %%
##RE EXECUTING THE DATA FOR FITTING MODELS
##step 3 D
##FINALLY we are combining all the pre-processed variables
##those are X continuous variables and Categorical variables
###we consider the new data that is df_newX for training and testing X variables
df_newX=pd.concat([df_cont,df_cat],axis=1)
df_newX
# Out:
#       Age_08_04        KM        HP  Automatic        cc     Doors  Cylinders  \
# 0     -1.771966 -0.574695 -0.768042  -0.242893  0.997419 -1.085139        0.0
# 1     -1.771966  0.117454 -0.768042  -0.242893  0.997419 -1.085139        0.0
# 2     -1.718184 -0.715386 -0.768042  -0.242893  0.997419 -1.085139        0.0
# 3     -1.610620 -0.547650 -0.768042  -0.242893  0.997419 -1.085139        0.0
# 4     -1.395491 -0.801028 -0.768042  -0.242893  0.997419 -1.085139        0.0
# ...         ...       ...       ...        ...       ...       ...        ...
# 1431   0.702015 -1.279939 -1.035138  -0.242893 -0.652594 -1.085139        0.0
# 1432   0.863362 -1.321120 -1.035138  -0.242893 -0.652594 -1.085139        0.0
# 1433   0.809579 -1.374036 -1.035138  -0.242893 -0.652594 -1.085139        0.0
# 1434   0.755797 -1.376703 -1.035138  -0.242893 -0.652594 -1.085139        0.0
# 1435   1.078490 -1.827849  0.567440  -0.242893  0.054555  1.014941        0.0
#
# ...

# %%
## step 4
####model 3

Y=df["Price"]

df_newX=df_newX[["Age_08_04","Weight","KM"]]


from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(df_newX,Y)
Y_pred=LR.predict(df_newX)

import numpy as np

from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(Y,Y_pred)
print("Mean Square error:",mse.round(3))
print("Root Mean Square error:",np.sqrt(mse).round(3))

print("R sqaure value:",r2_score(Y,Y_pred).round(3))
# Out:
# Mean Square error: 1996777.761
# Root Mean Square error: 1413.074
# R sqaure value: 0.848

# %%
## step 4
####model 4


Y=df["Price"]

df_newX=df_newX[["Age_08_04","Weight","KM",'HP']]


from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(df_newX,Y)
Y_pred=LR.predict(df_newX)

import numpy as np

from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(Y,Y_pred)
print("Mean Square error:",mse.round(3))
print("Root Mean Square error:",np.sqrt(mse).round(3))

print("R sqaure value:",r2_score(Y,Y_pred).round(3))
# Out:
# Mean Square error: 1817054.528
# Root Mean Square error: 1347.982
# R sqaure value: 0.862

# %%
## step 4
####model 5
Y=df["Price"]


df_newX=df_newX[["Age_08_04","Weight","KM",'HP','Doors']]


from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(df_newX,Y)
Y_pred=LR.predict(df_newX)

import numpy as np

from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(Y,Y_pred)
print("Mean Square error:",mse.round(3))
print("Root Mean Square error:",np.sqrt(mse).round(3))

print("R sqaure value:",r2_score(Y,Y_pred).round(3))
# Out:
# Mean Square error: 1816100.455
# Root Mean Square error: 1347.628
# R sqaure value: 0.862

# %%
## step 4
####model 6


Y=df["Price"]

df_newX=df_newX[["Age_08_04","Weight","KM",'HP','Doors','cc']]


from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(df_newX,Y)
Y_pred=LR.predict(df_newX)

import numpy as np

from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(Y,Y_pred)
print("Mean Square error:",mse.round(3))
print("Root Mean Square error:",np.sqrt(mse).round(3))

print("R sqaure value:",r2_score(Y,Y_pred).round(3))
# Out:
# Mean Square error: 1814805.46
# Root Mean Square error: 1347.147
# R sqaure value: 0.862

# %%
## step 4
####model 7


Y=df["Price"]

df_newX=df_newX[["Age_08_04","Weight","KM",'HP','Doors','cc','Gears']]


from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(df_newX,Y)
Y_pred=LR.predict(df_newX)

import numpy as np

from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(Y,Y_pred)
print("Mean Square error:",mse.round(3))
print("Root Mean Square error:",np.sqrt(mse).round(3))

print("R sqaure value:",r2_score(Y,Y_pred).round(3))
# Out:
# Mean Square error: 1802340.645
# Root Mean Square error: 1342.513
# R sqaure value: 0.863

# %%
## step 4
####model 8


Y=df["Price"]

df_newX=df_newX[["Age_08_04","Weight","KM",'HP','Doors','cc','Gears','Automatic']]


from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(df_newX,Y)
Y_pred=LR.predict(df_newX)

import numpy as np

from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(Y,Y_pred)
print("Mean Square error:",mse.round(3))
print("Root Mean Square error:",np.sqrt(mse).round(3))

print("R sqaure value:",r2_score(Y,Y_pred).round(3))
# Out:
# Mean Square error: 1795229.858
# Root Mean Square error: 1339.862
# R sqaure value: 0.863

# %%
## step 4
###model 9


Y=df["Price"]

df_newX=df_newX[["Age_08_04","Weight","KM",'HP','Doors','cc','Gears','Automatic','Fuel Type Encoded']]


from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(df_newX,Y)
Y_pred=LR.predict(df_newX)

import numpy as np

from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(Y,Y_pred)
print("Mean Square error:",mse.round(3))
print("Root Mean Square error:",np.sqrt(mse).round(3))

print("R sqaure value:",r2_score(Y,Y_pred).round(3))
# Out:
# Mean Square error: 1775881.052
# Root Mean Square error: 1332.622
# R sqaure value: 0.865

# %%
##4.Evaluate the performance of the model using appropriate evaluation metrics on the testing dataset.

# %%
##VARIANCE INFLUENCE FACTORS
##OBSERVING VIF VALUES BETWEEN X VARIABLES
## if the value is less than 5 we can accept the model

# %%
Y=df["Age_08_04"]
X=df[["Weight"]]
import statsmodels.formula.api as smf
model=smf.ols('Y~X',data=df).fit()
model.summary()
model.rsquared.round(2)
r2=model.rsquared
VIF=1/(1-r2)
print("VIF value: ",VIF)
# Out:
# VIF value:  1.2839245890191988

# %%
Y=df["Age_08_04"]
X=df[["KM"]]
import statsmodels.formula.api as smf
model=smf.ols('Y~X',data=df).fit()
model.summary()
model.rsquared.round(2)
r2=model.rsquared
VIF=1/(1-r2)
print("VIF value: ",VIF)
# Out:
# VIF value:  1.3435521293062285

# %%
Y=df["Age_08_04"]
X=df[["HP"]]
import statsmodels.formula.api as smf
model=smf.ols('Y~X',data=df).fit()
model.summary()
model.rsquared.round(2)
r2=model.rsquared
VIF=1/(1-r2)
print("VIF value: ",VIF)
# Out:
# VIF value:  1.0251473326599272

# %%
Y=df["Weight"]
X=df[["KM"]]
import statsmodels.formula.api as smf
model=smf.ols('Y~X',data=df).fit()
model.summary()
model.rsquared.round(2)
r2=model.rsquared
VIF=1/(1-r2)
print("VIF value: ",VIF)
# Out:
# VIF value:  1.0008185411887265

# %%
Y=df["KM"]
X=df[["Weight"]]
import statsmodels.formula.api as smf
model=smf.ols('Y~X',data=df).fit()
model.summary()
model.rsquared.round(2)
r2=model.rsquared
VIF=1/(1-r2)
print("VIF value: ",VIF)
# Out:
# VIF value:  1.0008185411887267

# %%
Y=df["Weight"]
X=df[["HP"]]
import statsmodels.formula.api as smf
model=smf.ols('Y~X',data=df).fit()
model.summary()
model.rsquared.round(2)
r2=model.rsquared
VIF=1/(1-r2)
print("VIF value: ",VIF)
# Out:
# VIF value:  1.0080956935596175

# %%
Y=df["KM"]
X=df[["HP"]]
import statsmodels.formula.api as smf
model=smf.ols('Y~X',data=df).fit()
model.summary()
model.rsquared.round(2)
r2=model.rsquared
VIF=1/(1-r2)
print("VIF value: ",VIF)
# Out:
# VIF value:  1.1251727229856463

# %%
Y=df["HP"]
X=df[["Doors"]]
import statsmodels.formula.api as smf
model=smf.ols('Y~X',data=df).fit()
model.summary()
model.rsquared.round(2)
r2=model.rsquared
VIF=1/(1-r2)
print("VIF value: ",VIF)
# Out:
# VIF value:  1.0086158868955668

# %%
#============================================================
# FINALIZED VARIABLES
Y = df['Price']
X = df[['Age_08_04','Weight','KM','HP']]
import statsmodels.formula.api as smf
model = smf.ols('Y ~ X',data=df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     2230.
# Date:                Sun, 30 Jun 2024   Prob (F-statistic):               0.00
# Time:                        15:02:35   Log-Likelihood:                -12386.
# No. Observations:                1436   AIC:                         2.478e+04
# Df Residuals:                    1431   BIC:                         2.481e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -4014.6418    936.044     -4.289      0.000   -5850.808   -2178.476
# ...

# %%
###REDISUAL ANALYSIS
model.resid ###y-y pred
import matplotlib.pyplot as plt
plt.hist(model.resid)
plt.show()
model.resid.skew()
# Out:
# -0.3844687580384154

# %%
##Q-Q plot 
##test for normality of residuals (Q-Q plot)
import matplotlib.pyplot as plt
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q') #line=45 to draw the diagonal line
plt.title(" Normal Q-Q plot of reiduals")
plt.show()

# %%
# Model Deletion Diagnostics
## Detecting Influencers/Outliers

## Cook’s Distance
(cooks, pvalue) = model.get_influence().cooks_distance

cooks = pd.DataFrame(cooks)

# %%
import matplotlib.pyplot as plt
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(df)), np.round(cooks[0], 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
# points which are greater than leverage value treated as influencer observations
cooks[0][cooks[0]>leverage_cutoff]
# Out:
# 14     0.037531
# 16     0.037665
# 49     0.035356
# 109    0.213647
# 110    0.123966
# 111    0.137230
# 115    0.023289
# 141    0.029482
# 191    0.035119
# 192    0.026130
# 221    1.269940
# 601    0.168191
# 654    0.038517
# 960    0.508615
# Name: 0, dtype: float64

# %%
# Leverage cutoff value
k = df_newX.shape[1]
n = df_newX.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff

#============================================================================
# Out:
# 0.004178272980501393

# %%
##LASSO AND RIDGE HAD IMPLEMENTED IN TWO SEPERATE FILES.

# %%
#Interview Questions:
#1.What is Normalization & Standardization and how is it helpful?`
#2.What techniques can be used to address multicollinearity in multiple linear regression?

# %%
#Standardisation is calculated by dividing the mean by the standard deviation.
#Normalisation, which entails dividing a vector by its length, converts data into a range between 0 and 1.

# %%
#Normalization or Min-Max Scaling is used to transform features to be on a similar scale. 
# scales the range to [0, 1] or sometimes [-1, 1].
#It is useful when we don’t know about the distribution

# %%
#Standardization or Z-Score Normalization is the transformation of features by subtracting from mean and dividing by standard deviation. 
#This is even called as Z-score.

#X_new = (X - mean)/sigma
#Standardization can be helpful in cases where the data follows a Gaussian distribution.

# %%
#It is useful when the feature distribution is Normal or Gaussian.

# %%
##Strategies to address Multicollinearity:
#Feature Selection:Dropping one of the correlated variables, prioritizing the most relevant. 

#Collect More Data:Increase our sample size in order to reduce the impact of multicollinearity.

#Transform Variables:
#Applying the mathematical transformations like standardization/normalization to thevariables. 
#we can also use the dimensionality reduction techniques like Principal Component Analysis (PCA) 

#Ridge or Lasso Regression:can implement the regularization techniques like Ridge or Lasso regression, 
#in order to reduce the impact of multicollinearity. 

#Variance Inflation Factor (VIF):Calculate the VIF scores for each variable; if VIF > 10, consider removing variables.
#vif<5 we can consider the model.

#Cross-Validation:Use cross-validation techniques for evaluating model's performance and 
#observe any if multicollinearity is negatively affecting predictions.
